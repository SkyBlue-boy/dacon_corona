# %% [markdown]
# # patient

# %% [markdown]
# ## overseas inflow

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import os
os.name
# Out:
# 'nt'

# %%
if os.name == "posix":
    sns.set(font="AppleGothic")
elif os.name == "nt":
    sns.set(font="Malgun Gothic")

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
# !move C:\Users\user\Downloads\dacon\KT-data\COVID_19\PatientInfo.csv .
# Out:
# 지정된 경로를 찾을 수 없습니다.

# %%
df_raw = pd.read_csv('PatientInfo.csv')
df_raw.shape
# Out:
# (5165, 14)

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5165 entries, 0 to 5164
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   patient_id          5165 non-null   int64
#  1   sex                 4043 non-null   object
#  2   age                 3785 non-null   object
#  3   country             5165 non-null   object
#  4   province            5165 non-null   object
#  5   city                5071 non-null   object
#  6   infection_case      4246 non-null   object
#  7   infected_by         1346 non-null   object
#  8   contact_number      791 non-null    object
#  9   symptom_onset_date  690 non-null    object
#  10  confirmed_date      5162 non-null   object
#  11  released_date       1587 non-null   object
#  12  deceased_date       66 non-null     object
#  13  state               5165 non-null   object
# dtypes: int64(1), object(13)
# memory usage: 565.0+ KB

# %%
case = df_raw['infection_case']
case
# Out:
# 0            overseas inflow
# 1            overseas inflow
# 2       contact with patient
# 3            overseas inflow
# 4       contact with patient
#                 ...
# 5160         overseas inflow
# 5161         overseas inflow
# 5162         overseas inflow
# 5163         overseas inflow
# 5164         overseas inflow
# Name: infection_case, Length: 5165, dtype: object

# %%
df_overseas = df_raw[df_raw['infection_case']=='overseas inflow']
df_overseas
# Out:
#       patient_id     sex  age     country province city   infection_case  \
# 0     1000000001    male  50s       Korea       서울  강서구  overseas inflow
# 1     1000000002    male  30s       Korea       서울  중랑구  overseas inflow
# 3     1000000004    male  20s       Korea       서울  마포구  overseas inflow
# 7     1000000008    male  20s       Korea       서울   기타  overseas inflow
# 8     1000000009    male  30s       Korea       서울  송파구  overseas inflow
# ...          ...     ...  ...         ...      ...  ...              ...
# 5160  7000000015  female  30s       Korea      제주도  제주도  overseas inflow
# 5161  7000000016     NaN  NaN       Korea      제주도  제주도  overseas inflow
# 5162  7000000017     NaN  NaN  Bangladesh      제주도  제주도  overseas inflow
# 5163  7000000018     NaN  NaN  Bangladesh      제주도  제주도  overseas inflow
# 5164  7000000019     NaN  NaN  Bangladesh      제주도  제주도  overseas inflow
#
#      infected_by contact_number symptom_onset_date confirmed_date  \
# ...

# %%
df_overseas.isnull()
# Out:
#       patient_id    sex    age  country  province   city  infection_case  \
# 0          False  False  False    False     False  False           False
# 1          False  False  False    False     False  False           False
# 3          False  False  False    False     False  False           False
# 7          False  False  False    False     False  False           False
# 8          False  False  False    False     False  False           False
# ...          ...    ...    ...      ...       ...    ...             ...
# 5160       False  False  False    False     False  False           False
# 5161       False   True   True    False     False  False           False
# 5162       False   True   True    False     False  False           False
# 5163       False   True   True    False     False  False           False
# 5164       False   True   True    False     False  False           False
#
#       infected_by  contact_number  symptom_onset_date  confirmed_date  \
# ...

# %%
null_count = df_overseas.isnull().sum()
null_count
# Out:
# patient_id              0
# sex                   166
# age                   187
# country                 0
# province                0
# city                   19
# infection_case          0
# infected_by           830
# contact_number        677
# symptom_onset_date    713
# confirmed_date          0
# released_date         651
# deceased_date         840
# state                   0
# dtype: int64

# %%
df_raw['contact_number']
# Out:
# 0        75
# 1        31
# 2        17
# 3         9
# 4         2
#        ...
# 5160     25
# 5161    NaN
# 5162     72
# 5163    NaN
# 5164    NaN
# Name: contact_number, Length: 5165, dtype: object

# %%
df_overseas['confirmed_date']=df_overseas['confirmed_date'].astype(str)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_overseas['month']=df_overseas['confirmed_date'].str.slice(start=5, stop=7)
df_overseas.head()
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#    patient_id   sex  age country province city   infection_case infected_by  \
# 0  1000000001  male  50s   Korea       서울  강서구  overseas inflow         NaN
# 1  1000000002  male  30s   Korea       서울  중랑구  overseas inflow         NaN
# 3  1000000004  male  20s   Korea       서울  마포구  overseas inflow         NaN
# 7  1000000008  male  20s   Korea       서울   기타  overseas inflow         NaN
# 8  1000000009  male  30s   Korea       서울  송파구  overseas inflow         NaN
#
#    contact_number symptom_onset_date                 confirmed_date  \
# ...

# %%
df_overseas['contact_number']= df_overseas['contact_number'].replace('-', pd.np.nan).astype(float)
df_overseas['contact_number']
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   """Entry point for launching an IPython kernel.
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0       75.0
# 1       31.0
# 3        9.0
# 7        0.0
# 8       68.0
#         ...
# 5160    25.0
# 5161     NaN
# 5162    72.0
# 5163     NaN
# 5164     NaN
# Name: contact_number, Length: 840, dtype: float64

# %% [markdown]
# ## domestic inflow

# %% [markdown]
# ## age

# %% [markdown]
# ## gender
