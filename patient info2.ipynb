# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import os
os.name
# Out:
# 'nt'

# %%
if os.name == "posix":
    sns.set(font="AppleGothic")
elif os.name == "nt":
    sns.set(font="Malgun Gothic")

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
df_raw = pd.read_csv('PatientInfo.csv')
df_raw.shape
# Out:
# (5165, 14)

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5165 entries, 0 to 5164
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   patient_id          5165 non-null   int64
#  1   sex                 4043 non-null   object
#  2   age                 3785 non-null   object
#  3   country             5165 non-null   object
#  4   province            5165 non-null   object
#  5   city                5071 non-null   object
#  6   infection_case      4246 non-null   object
#  7   infected_by         1346 non-null   object
#  8   contact_number      791 non-null    object
#  9   symptom_onset_date  690 non-null    object
#  10  confirmed_date      5162 non-null   object
#  11  released_date       1587 non-null   object
#  12  deceased_date       66 non-null     object
#  13  state               5165 non-null   object
# dtypes: int64(1), object(13)
# memory usage: 565.0+ KB

# %%
sns.countplot(x = 'infection_case', data = df_raw)
plt.title('감염경로')
plt.xticks(rotation=70)
plt.show()

# %%
df_infection_case = df_raw['infection_case']

# %%
df_raw['infection_case'] = pd.to_numeric(df_raw['infection_case'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "overseas inflow"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-2ffe1d974e70> in <module>
# ----> 1 df_raw['infection_case'] = pd.to_numeric(df_raw['infection_case'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     148         try:
#     149             values = lib.maybe_convert_numeric(
# --> 150                 values, set(), coerce_numeric=coerce_numeric
#     151             )
#     152         except (ValueError, TypeError):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ...

# %%
df_infection_case.plot.barh()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-102793485a96> in <module>
# ----> 1 df_infection_case.plot.barh()
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in barh(self, x, y, **kwargs)
#    1081             >>> ax = df.plot.barh(x='lifespan')
#    1082         """
# -> 1083         return self(kind="barh", x=x, y=y, **kwargs)
#    1084
#    1085     def box(self, by=None, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
# ...
